# %% [markdown]
# ## Imports

# %%
from numpy.lib import median
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import os
import seaborn as sns
from scipy.interpolate import UnivariateSpline
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from aeon.distances import dtw_distance, euclidean_distance
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.model_selection import train_test_split
from aeon.transformations.collection import PaddingTransformer

# %% [markdown]
# ## Carga da base

# %%
df_total = pd.DataFrame()
for i in os.listdir('normalizacao/'):
    df = pd.read_excel(f"normalizacao/{i}",header=None)
    df['Nome'] = i.split('-')[1].split('.')[0]
    df_total = pd.concat([df,df_total])
df_total = df_total.rename(columns={1:'Qtd Total Pontos',2:'Qtd Dados'})

# %%
df_total['Fadiga'] = [0 if x == 'Normal' else 1 for x in df_total[0]]
df_total
# Out:
#           0  Qtd Total Pontos  Qtd Dados           3           4           5  \
# 0    Normal               209        209  567.446533  568.821289  566.604553
# 1    Normal               300        300  879.816956  879.942139  879.928650
# 2     Platô              2836       2833  572.095398  572.401611  571.013062
# 3    Normal               232        232  870.932861  870.796021  870.880981
# 4    Normal               243        243  565.241333  567.252869  565.120483
# ..      ...               ...        ...         ...         ...         ...
# 232  Normal               195        195  582.270752  582.312927  582.332642
# 233  Normal               204        204  823.033081  822.782959  822.402832
# 234  Normal               202        201  581.130737  581.057129  581.105042
# 235  Normal               226        224  821.867798  821.840637  821.707642
# 236  Normal               209        209  592.194275  593.707458  594.013184
#
#               6           7           8           9  ...  6998  6999  7000  \
# 0    569.215271  567.596497  568.547424  566.788452  ...   NaN   NaN   NaN
# 1    879.803467  879.663269  879.543823  879.566345  ...   NaN   NaN   NaN
# 2    572.802307  570.430603  573.321533  570.844543  ...   NaN   NaN   NaN
# 3    870.852600  870.916504  870.940430  871.018433  ...   NaN   NaN   NaN
# 4    567.405396  565.388672  567.268066  565.052429  ...   NaN   NaN   NaN
# ..          ...         ...         ...         ...  ...   ...   ...   ...
# 232  582.324463  582.339294  582.328979  582.372803  ...   NaN   NaN   NaN
# 233  822.113342  821.986511  822.004822  821.789124  ...   NaN   NaN   NaN
# 234  581.154541  581.246277  581.339111  581.391541  ...   NaN   NaN   NaN
# 235  821.677490  821.820312  821.877625  821.798767  ...   NaN   NaN   NaN
# 236  595.604187  596.620544  597.616394  598.595764  ...   NaN   NaN   NaN
#
#      7001  7002  7003  7004  7005  7006  Fadiga
# 0     NaN   NaN   NaN   NaN   NaN   NaN       0
# 1     NaN   NaN   NaN   NaN   NaN   NaN       0
# 2     NaN   NaN   NaN   NaN   NaN   NaN       1
# 3     NaN   NaN   NaN   NaN   NaN   NaN       0
# 4     NaN   NaN   NaN   NaN   NaN   NaN       0
# ..    ...   ...   ...   ...   ...   ...     ...
# 232   NaN   NaN   NaN   NaN   NaN   NaN       0
# 233   NaN   NaN   NaN   NaN   NaN   NaN       0
# 234   NaN   NaN   NaN   NaN   NaN   NaN       0
# 235   NaN   NaN   NaN   NaN   NaN   NaN       0
# 236   NaN   NaN   NaN   NaN   NaN   NaN       0
#
# [8538 rows x 7009 columns]

# %% [markdown]
# ## Pipeline de Tratamentos

# %%
def pipeline_knn(df_total, seed, sampler = 'Under'):
    #Separar em Treino e Teste
    #12 treino 6 teste
    X = df_total.drop([0,'Fadiga','Qtd Dados','%De N Vazios'], axis=1)
    y = df_total[['Fadiga','Nome']]

    aleatorio = np.random.default_rng(seed = seed)
    nome_treino = aleatorio.choice(np.unique(df_total['Nome']), size=12, replace=False)
    nome_test = set(np.unique(df_total['Nome'])).difference(nome_treino)
    print(f'Pessoas Treino: {nome_treino}')
    print(f'Pessoas Teste: {np.array(nome_test)}')

    train_data = X[X['Nome'].isin(nome_treino)].drop(['Nome'],axis=1)
    train_labels = y[y['Nome'].isin(nome_treino)]['Fadiga']
    test_data = X[X['Nome'].isin(nome_test)].drop(['Nome'],axis=1)
    test_labels = y[y['Nome'].isin(nome_test)]['Fadiga']
    # random_seed = 40
    # train_data, test_data, train_labels, test_labels = train_test_split(X.drop(['Nome'], axis=1), y['Fadiga'],
    #                        train_size=0.7,
    #                        test_size=0.3,
    #                        random_state=random_seed)
    
    # #Porção do treinamento fica para validação (70-30)
    # train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels,
    #                        train_size=0.7,
    #                        test_size=0.3,
    #                        random_state=random_seed)

    
    print(f'Quantidade Treino: {len(train_data)}')
    print(f'Quantidade Teste: {len(test_data)}')

    #Balanceamento de Dados
    train_data.columns = train_data.columns.astype(str)
    print(train_labels.value_counts())
    if sampler == 'Under':
        rus = RandomUnderSampler()
    elif sampler == 'Over':
        rus = RandomOverSampler()
    train_data_re, train_labels_re = rus.fit_resample(train_data, train_labels)
    #train_data_re, train_labels_re = train_data, train_labels
    
    print(train_labels_re.value_counts())
    
    segmentos_treino = []
    train_qtd = train_data_re['Qtd Total Pontos'].values
    count = 0
    for linha in train_data_re.drop(['Qtd Total Pontos'],axis=1).values:
        serie = linha[:train_qtd[count]]
        serie = pd.Series(serie).interpolate().to_numpy()
        if pd.isna(serie[0]):
            serie = serie[1:]
        segmentos_treino.append(serie)
        count += 1
    segmentos_test = []
    test_qtd = test_data['Qtd Total Pontos'].values
    count = 0
    for linha in test_data.drop(['Qtd Total Pontos'],axis=1).values:
        serie = linha[:test_qtd[count]]
        serie = pd.Series(serie).interpolate().to_numpy()
        if pd.isna(serie[0]):
            serie = serie[1:]
        segmentos_test.append(serie)
        count += 1
    return segmentos_treino, train_labels_re.values, segmentos_test, test_labels.values

# %%
def pipeline_outros(df_total, seed, sampler = 'Under'):
    #Separar em Treino e Teste
    #12 treino 6 teste
    X = df_total.drop([0,'Fadiga'], axis=1)
    y = df_total[['Fadiga','Nome']]

    aleatorio = np.random.default_rng(seed = seed)
    nome_treino = aleatorio.choice(np.unique(df_total['Nome']), size=12, replace=False)
    nome_test = set(np.unique(df_total['Nome'])).difference(nome_treino)
    print(f'Pessoas Treino: {nome_treino}')
    print(f'Pessoas Teste: {np.array(nome_test)}')

    train_data = X[X['Nome'].isin(nome_treino)].drop(['Nome'],axis=1)
    train_labels = y[y['Nome'].isin(nome_treino)].drop(['Nome'],axis=1)
    test_data = X[X['Nome'].isin(nome_test)].drop(['Nome'],axis=1)
    test_labels = y[y['Nome'].isin(nome_test)].drop(['Nome'],axis=1)
    
    print(f'Quantidade Treino: {len(train_data)}')
    print(f'Quantidade Teste: {len(test_data)}')

    #Balanceamento de Dados

    print(train_labels['Fadiga'].value_counts())
    if sampler == 'Under':
        rus = RandomUnderSampler()
    elif sampler == 'Over':
        rus = RandomOverSampler()
    train_data_re, train_labels_re = rus.fit_resample(train_data, train_labels)
    
    print(train_labels_re['Fadiga'].value_counts())

    #Igualar Tamanhos
    padder = PaddingTransformer(pad_length=200, fill_value =0)
    segmento_x2 = padder.fit_transform(train_data_re)
    
    return segmento_x2, train_labels_re['Fadiga'], test_data, test_labels['Fadiga']

# %%
def test_uma_pessoa (df):
    segmentos = []
    train_qtd = df['Qtd Total Pontos'].values
    count = 0
    for linha in df.drop([0,'Fadiga','Nome','Qtd Dados','Qtd Total Pontos','%De N Vazios'],axis=1).values:
        serie = linha[:train_qtd[count]]
        serie = pd.Series(serie).interpolate().to_numpy()
        if pd.isna(serie[0]):
            serie = serie[1:]
        segmentos.append(serie)
        count += 1
    labels = df['Fadiga']
    return segmentos, labels.values

# %% [markdown]
# Filtro Baseado na Analise

# %%
df_total['%De N Vazios'] = df_total['Qtd Dados'] / df_total['Qtd Total Pontos']
df_filtrado = df_total[(df_total['%De N Vazios'] > 0.85) 
    & (df_total[0] != 'Erro na Coleta') 
    & (df_total['Qtd Total Pontos'] < 500) 
    & (df_total['Nome'] != 'Josefina')
]

# %%
teste =df_total.groupby(['Nome'])['Fadiga'].value_counts()
print(teste)
# Out:
# Nome       Fadiga
# Adilson    0          235
#            1            2
# Amaro      0          538
#            1           70
# Arnaldo    0          312
#            1          301
# Carlos     1          228
#            0          118
# Elisabete  0          368
#            1           64
# Iria       0          149
#            1           22
# Izabel     0          443
#            1           20
# Jair       0          904
#            1           57
# Josefina   0           48
#            1           22
# Josui      0          459
#            1           55
# Katia      0          116
#            1            5
# Marilene   0          334
#            1          151
# Nelson     0          141
#            1            7
# Reinaldo   0          780
#            1           68
# Teresinha  0          316
#            1           32
# Valdir     0         1253
#            1           47
# ilda       0          642
#            1           42
# mariajose  0          175
#            1           14
# Name: count, dtype: int64

# %%
teste =df_total.groupby(['Nome'])['Fadiga'].value_counts()
nome = []
classe = []
for i in teste.index:
    nome.append(i[0])
    if i[1] == 1:
        classe.append('Anormal')
    else:
        classe.append('Normal')
df_teste = pd.DataFrame({'value':teste.values,'nome':nome,'classe':classe})
#f, ax = plt.subplots(figsize=(6, 15))
ax = sns.barplot(df_teste,x='value',y='nome',hue='classe')
ax.bar_label(ax.containers[0], fontsize=7);
ax.bar_label(ax.containers[1], fontsize=7);
ax.legend(ncol=2, loc="lower right", frameon=True)

# %%
teste = df_filtrado.groupby(['Nome'])['Fadiga'].value_counts()
nome = []
classe = []
for i in teste.index:
    nome.append(i[0])
    if i[1] == 1:
        classe.append('Anormal')
    else:
        classe.append('Normal')
df_teste = pd.DataFrame({'value':teste.values,'nome':nome,'classe':classe})
#f, ax = plt.subplots(figsize=(6, 15))
ax = sns.barplot(df_teste,x='value',y='nome',hue='classe')
ax.bar_label(ax.containers[0], fontsize=7);
ax.bar_label(ax.containers[1], fontsize=7);
ax.legend(ncol=2, loc="lower right", frameon=True)

# %% [markdown]
# ## KNN

# %%
train_data, train_labels, test_data, test_labels = pipeline_knn(df_filtrado,seed = 39,sampler = 'Under')

train_data_x = []
for i in train_data:
    train_data_x.append(np.array(i).reshape(1,len(i)))
test_data_x = []
for i in test_data:
    test_data_x.append(np.array(i).reshape(1,len(i)))
train_labels_y = np.array(train_labels)
test_labels_y = np.array(test_labels)
# Out:
# Pessoas Treino: ['Jair' 'Iria' 'Reinaldo' 'Izabel' 'Elisabete' 'Josui' 'Nelson' 'Marilene'
#  'Amaro' 'Teresinha' 'Carlos' 'mariajose']
# Pessoas Teste: {'Katia', 'Arnaldo', 'Adilson', 'ilda', 'Valdir'}
# Quantidade Treino: 5451
# Quantidade Teste: 2944
# Fadiga
# 0    4713
# 1     738
# Name: count, dtype: int64
# Fadiga
# 0    738
# 1    738
# Name: count, dtype: int64

# %%
classifier = KNeighborsTimeSeriesClassifier(distance=dtw_distance, n_neighbors = 5)
classifier.fit(train_data_x, train_labels_y)
# Out:
# KNeighborsTimeSeriesClassifier(distance=CPUDispatcher(<function dtw_distance at 0x000001F2EED994E0>),
#                                n_neighbors=5)

# %%
#computa as classes para todos
predicts = classifier.predict(test_data_x)

from sklearn.metrics import accuracy_score
acc = accuracy_score(test_labels,predicts)
print(acc)
# Out:
# 0.7691256830601093

# %%
from sklearn.metrics import classification_report
print(classification_report(test_labels,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87      2821
#            1       0.05      0.28      0.08       107
#
#     accuracy                           0.77      2928
#    macro avg       0.51      0.53      0.47      2928
# weighted avg       0.93      0.77      0.84      2928

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_predictions(test_labels,predicts)

# %%
#Mostrando TP, TN, FP, FN
tp = []
tn = []
fp = []
fn = []
real = test_labels.values
for x in range(len(test_data_x)):
    if len(tp) + len(tn) + len(fp) + len(fn) == 20:
        break
    if (real[x] == 1 and predicts[x] == 1 and len(tp) < 5):
        tp.append(test_data_x[x])
    if (real[x] == 0 and predicts[x] == 0 and len(tn) < 5):
        tn.append(test_data_x[x])
    if (real[x] == 0 and predicts[x] == 1 and len(fp) < 5):
        fp.append(test_data_x[x])
    if (real[x] == 1 and predicts[x] == 0 and len(fn) < 5):
        fn.append(test_data_x[x])
# Out:
# [0 0 0 ... 0 0 0]

# %%
for x in fn:
    plt.plot(x[0])
    plt.title('False Negative - Anormal')
    plt.show()

# %% [markdown]
# ## C22

# %%
train_data, train_labels, test_data, test_labels = pipeline_knn(df_filtrado,seed = 39,sampler = 'Under')

train_data_x = []
for i in train_data:
    train_data_x.append(np.array(i).reshape(1,len(i)))
test_data_x = []
for i in test_data:
    test_data_x.append(np.array(i).reshape(1,len(i)))
train_labels_y = np.array(train_labels)
test_labels_y = np.array(test_labels)
# Out:
# Pessoas Treino: ['Jair' 'Iria' 'Reinaldo' 'Izabel' 'Elisabete' 'Josui' 'Nelson' 'Marilene'
#  'Amaro' 'Teresinha' 'Carlos' 'mariajose']
# Pessoas Teste: {'Katia', 'Arnaldo', 'Adilson', 'ilda', 'Valdir'}
# Quantidade Treino: 5451
# Quantidade Teste: 2944
# Fadiga
# 0    4713
# 1     738
# Name: count, dtype: int64
# Fadiga
# 0    738
# 1    738
# Name: count, dtype: int64

# %%
from aeon.classification.feature_based import Catch22Classifier
from sklearn.ensemble import RandomForestClassifier
from aeon.testing.data_generation import make_example_3d_numpy
from aeon.classification.deep_learning import TimeCNNClassifier
clf = Catch22Classifier(
    estimator = KNeighborsTimeSeriesClassifier(distance=dtw_distance, n_neighbors = 5), #RandomForestClassifier(n_estimators=100),
    replace_nans=True,
    outlier_norm=True,
    random_state=0,
)
clf.fit(train_data_x, train_labels_y)
# Out:
# Catch22Classifier(estimator=KNeighborsTimeSeriesClassifier(distance=CPUDispatcher(<function dtw_distance at 0x000001F6E9ACD760>),
#                                                            n_neighbors=5),
#                   outlier_norm=True, random_state=0)

# %%
predicts = clf.predict(test_data_x)

from sklearn.metrics import accuracy_score
acc = accuracy_score(test_labels,predicts)
print(acc)
# Out:
# 0.4921875

# %%
from sklearn.metrics import classification_report
print(classification_report(test_labels,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.44      0.60      2558
#            1       0.19      0.85      0.31       386
#
#     accuracy                           0.49      2944
#    macro avg       0.57      0.65      0.45      2944
# weighted avg       0.85      0.49      0.56      2944

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_predictions(test_labels,predicts)

# %% [markdown]
# ### Classificação de 1 pessoa

# %%
pessoa, labels = test_uma_pessoa(df_filtrado[df_filtrado['Nome'] == 'Arnaldo'])
pessoa_x = []
for i in pessoa:
    pessoa_x.append(np.array(i).reshape(1,len(i)))
labels_y = np.array(labels)

# %%
predicts = clf.predict(pessoa_x)

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_y,predicts)
print(acc)
# Out:
# 0.5586776859504132

# %%
from sklearn.metrics import classification_report
print(classification_report(labels_y,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.18      0.30       312
#            1       0.52      0.96      0.68       293
#
#     accuracy                           0.56       605
#    macro avg       0.68      0.57      0.49       605
# weighted avg       0.68      0.56      0.48       605

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_predictions(labels_y,predicts)

# %%
y = 0
count = 0
column_y = []
column_x = []
label = []
for serie in pessoa_x:
    for line in serie:
        for x in line:
            column_y.append(y)
            column_x.append(x)
            label.append(labels_y[count])
            if labels_y[count] == 1:
                column_y.append(y)
                column_x.append(np.nan)
                label.append(0)  
            else:
                column_y.append(y)
                column_x.append(np.nan)
                label.append(0)  
            y += 1
        count += 1 
teste_df = pd.DataFrame({'x':column_x,'y':column_y,'label':label})

# %%
teste_df.to_excel("resultados\Arnaldo.xlsx", index=False)

# %% [markdown]
# ## CNN

# %%
from aeon.registry import all_estimators

all_estimators(
    estimator_types="classifier", filter_tags={"capability:unequal_length": True}
)
# Out:
# C:\Users\le_du\anaconda3\Lib\site-packages\aeon\base\__init__.py:24: FutureWarning: The aeon package will soon be releasing v1.0.0 with the removal of legacy modules and interfaces such as BaseTransformer and BaseForecaster. This will contain breaking changes. See aeon-toolkit.org for more information. Set aeon.AEON_DEPRECATION_WARNING or the AEON_DEPRECATION_WARNING environmental variable to 'False' to disable this warning.
#   warnings.warn(
# [('Catch22Classifier',
#   aeon.classification.feature_based._catch22.Catch22Classifier),
#  ('DummyClassifier', aeon.classification.dummy.DummyClassifier),
#  ('ElasticEnsemble',
#   aeon.classification.distance_based._elastic_ensemble.ElasticEnsemble),
#  ('KNeighborsTimeSeriesClassifier',
#   aeon.classification.distance_based._time_series_neighbors.KNeighborsTimeSeriesClassifier),
#  ('RDSTClassifier', aeon.classification.shapelet_based._rdst.RDSTClassifier)]

# %%
segmentos_x = []
for i in segmentos:
    segmentos_x.append(np.array(i).reshape(1,len(i)))

# %%
from aeon.transformations.collection import PaddingTransformer
padder = PaddingTransformer(pad_length=200, fill_value =0)
segmento_x2 = padder.fit_transform(segmentos_x)

# %%
#70% treino - 30% test
random_seed = 40
train_data, test_data, train_labels, test_labels = train_test_split(segmento_x2, df_y,
                       train_size=0.7,
                       test_size=0.3,
                       random_state=random_seed)

#Porção do treinamento fica para validação (70-30)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels,
                       train_size=0.7,
                       test_size=0.3,
                       random_state=random_seed)

# %%
from aeon.classification.deep_learning import TimeCNNClassifier
classifier = TimeCNNClassifier(n_epochs=20, batch_size=4)
classifier.fit(train_data, train_labels)

# %%
#computa as classes para todos
predicts = classifier.predict(test_data)

from sklearn.metrics import accuracy_score
acc = accuracy_score(test_labels,predicts)
print(acc)

# %%
from sklearn.metrics import classification_report
print(classification_report(test_labels,predicts))

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_predictions(test_labels, predicts)
