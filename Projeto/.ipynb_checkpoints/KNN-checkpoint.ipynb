# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import accuracy_score
from scipy.interpolate import UnivariateSpline
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import GroupShuffleSplit
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.model_selection import train_test_split
from aeon.distances import dtw_distance, euclidean_distance
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier
from aeon.transformations.collection import PaddingTransformer
from aeon.classification.feature_based import Catch22Classifier
from aeon.testing.data_generation import make_example_3d_numpy
from aeon.classification.deep_learning import TimeCNNClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# ## Carga da base

# %%
df_total = pd.DataFrame()
for i in os.listdir('normalizacao/'):
    df = pd.read_excel(f"normalizacao/{i}",header=None)
    df['Nome'] = i.split('-')[1].split('.')[0]
    df_total = pd.concat([df,df_total])
df_total = df_total.rename(columns={1:'Qtd Total Pontos',2:'Qtd Dados'})

# %%
df_total[0].unique()
# Out:
# array(['Normal', 'Erro na Coleta', 'Platô', 'Dupla', 'Erro no Exercicio',
#        'Ritmo', 'Duplo', 'Normalr', 'Pré-Pico', 'PP', 'ritmo', 'Plato'],
#       dtype=object)

# %%
df_total['Fadiga'] = [0 if x == 'Normal' else 1 for x in df_total[0]]
df_total
# Out:
#                   0  Qtd Total Pontos  Qtd Dados           3           4  \
# 0            Normal               250        249  617.690186  617.679871
# 1            Normal               206        206  905.522034  905.256958
# 2    Erro na Coleta              1290        689  599.337158  603.076416
# 3    Erro na Coleta               120         99  750.602417  749.031067
# 4    Erro na Coleta               277         92  624.175659  624.377319
# ..              ...               ...        ...         ...         ...
# 166          Normal               177        175  585.330566  585.392761
# 167          Normal               226        225  869.773010  869.624756
# 168          Normal               212        212  586.307861  586.316895
# 169          Normal               200        200  862.808289  863.046753
# 170          Normal               251        250  587.927490  587.966492
#
#               5           6           7           8           9  ...  6998  \
# 0    617.748291  617.704529  617.624207  617.557251  617.412354  ...   NaN
# 1    905.053467  904.930481  904.830872  904.792175  904.865112  ...   NaN
# 2    606.548157  609.216492  610.949463  611.528442  611.240906  ...   NaN
# 3    747.358887  745.603943  743.997986  742.309265  740.471191  ...   NaN
# 4    624.488586  624.601196  624.832397  625.039429  625.369690  ...   NaN
# ..          ...         ...         ...         ...         ...  ...   ...
# 166  585.384583  585.461975  585.557800  585.493591  585.342041  ...   NaN
# 167  869.500549  869.216614  869.062622  868.875000  868.664856  ...   NaN
# 168  586.388367  586.399536  586.374939  586.223206  586.212463  ...   NaN
# 169  863.196655  863.211609  863.170715  863.205017  863.242798  ...   NaN
# 170  588.002808  588.005859  587.982727  587.918945  587.883606  ...   NaN
#
#      6999  7000  7001  7002  7003  7004  7005  7006  Fadiga
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# ..    ...   ...   ...   ...   ...   ...   ...   ...     ...
# 166   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 167   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 168   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 169   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 170   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
# [8538 rows x 7009 columns]

# %% [markdown]
# ## Pipeline de Tratamentos

# %%
nomes = df_total['Nome'].to_numpy()
X = df_total.drop([0,'Fadiga','Qtd Dados','Nome'], axis=1)
gss = GroupShuffleSplit(n_splits = 5, train_size = 12, test_size = 5)

train = gss.split(X=X, groups=nomes)
print(train)
# for i, (train_index, test_index) in enumerate(gss.split(X=X, groups=nomes)):
#     print(i)
#     print(np.unique(nomes[train_index]))
#     print(np.unique(nomes[test_index]))
# Out:
# <generator object BaseShuffleSplit.split at 0x71e818433440>

# %%
def pipeline_knn(df_total, seed, n_splits = 5, sampler = 'Under'):
    #Separar em Treino e Teste
    #12 treino 5 teste
    X = df_total.drop([0,'Fadiga','Qtd Dados','%De N Vazios','Nome'], axis=1)
    y = df_total['Fadiga']
    group = df_total['Nome'].to_numpy()

    gss = GroupShuffleSplit(n_splits = n_splits, train_size = 12, test_size = 5, random_state = seed)

    lista_data_train= []
    lista_labels_train = []
    lista_data_test = []
    lista_labels_test = []
    for i, (train_index, test_index) in enumerate(gss.split(X=X, groups=group)):
        print(f'Fold {i}')
        print(f'Pessoas Treino: {np.unique(group[train_index])}')
        print(f'Pessoas Teste: {np.unique(group[test_index])}')

        train_data = X.loc[train_index]
        train_labels = y.loc[train_index]
        test_data = X.loc[test_index]
        test_labels = y.loc[test_index]

    
        print(f'Quantidade Treino: {len(train_data)}')
        print(f'Quantidade Teste: {len(test_data)}')

        #Balanceamento de Dados
        train_data.columns = train_data.columns.astype(str)
        print(train_labels.value_counts())
        if sampler == 'Under':
            rs = RandomUnderSampler(random_state = seed)
        elif sampler == 'Over':
            rs = RandomOverSampler(random_state = seed)
        train_data_re, train_labels_re = rs.fit_resample(train_data, train_labels)
        #train_data_re, train_labels_re = train_data, train_labels
    
        print(train_labels_re.value_counts())

        #Interpolacao dos Segmentos
        segmentos_treino = []
        train_qtd = train_data_re['Qtd Total Pontos'].values
        count = 0
        for linha in train_data_re.drop(['Qtd Total Pontos'],axis=1).values:
            serie = linha[:train_qtd[count]]
            serie = pd.Series(serie).interpolate().to_numpy()
            if pd.isna(serie[0]):
                serie = serie[1:]
            segmentos_treino.append(serie)
            count += 1
        segmentos_test = []
        test_qtd = test_data['Qtd Total Pontos'].values
        count = 0
        for linha in test_data.drop(['Qtd Total Pontos'],axis=1).values:
            serie = linha[:test_qtd[count]]
            serie = pd.Series(serie).interpolate().to_numpy()
            if pd.isna(serie[0]):
                serie = serie[1:]
            segmentos_test.append(serie)
            count += 1

        #Colocando no Shape necessario
        train_data_x = []
        for i in segmentos_treino:
            train_data_x.append(np.array(i).reshape(1,len(i)))
        test_data_x = []
        for i in segmentos_test:
            test_data_x.append(np.array(i).reshape(1,len(i)))
        train_labels_y = np.array(train_labels_re.values)
        test_labels_y = np.array(test_labels.values)

        #Coloca na lista de Splits
        lista_data_train.append(train_data_x)
        lista_labels_train.append(train_labels_y)
        lista_data_test.append(test_data_x)
        lista_labels_test.append(test_labels_y)

    
    return lista_data_train, lista_labels_train, lista_data_test, lista_labels_test

# %%
def test_uma_pessoa (df):
    segmentos = []
    train_qtd = df['Qtd Total Pontos'].values
    count = 0
    for linha in df.drop([0,'Fadiga','Nome','Qtd Dados','Qtd Total Pontos','%De N Vazios'],axis=1).values:
        serie = linha[:train_qtd[count]]
        serie = pd.Series(serie).interpolate().to_numpy()
        if pd.isna(serie[0]):
            serie = serie[1:]
        segmentos.append(serie)
        count += 1
    labels = df['Fadiga']
    return segmentos, labels.values

# %% [markdown]
# Filtro Baseado na Analise

# %%
df_total['%De N Vazios'] = df_total['Qtd Dados'] / df_total['Qtd Total Pontos']
df_filtrado = df_total[(df_total['%De N Vazios'] > 0.85) 
    & (df_total[0] != 'Erro na Coleta') 
    & ((df_total['Qtd Total Pontos'] < 500) | (df_total[0] == 'Platô'))  
    & (df_total['Qtd Total Pontos'] < 1000)
    & (df_total['Nome'] != 'Josefina')
]
df_filtrado = df_filtrado.reset_index(drop=True)

# %% [markdown]
# ## KNN com Catch 22

# %%
seed = 10
train_data_x, train_labels_y, test_data_x, test_labels_y = pipeline_knn(df_filtrado,seed = seed,n_splits = 10,sampler = 'Under')
# Out:
# Fold 0
# Pessoas Treino: ['Adilson' 'Amaro' 'Arnaldo' 'Elisabete' 'Josui' 'Katia' 'Marilene'
#  'Nelson' 'Reinaldo' 'Teresinha' 'ilda' 'mariajose']
# Pessoas Teste: ['Carlos' 'Iria' 'Izabel' 'Jair' 'Valdir']
# Quantidade Treino: 5178
# Quantidade Teste: 3219
# Fadiga
# 0    4410
# 1     768
# Name: count, dtype: int64
# Fadiga
# 0    768
# 1    768
# Name: count, dtype: int64
# Fold 1
# Pessoas Treino: ['Adilson' 'Amaro' 'Carlos' 'Elisabete' 'Izabel' 'Josui' 'Katia'
#  'Marilene' 'Nelson' 'Reinaldo' 'Teresinha' 'mariajose']
# Pessoas Teste: ['Arnaldo' 'Iria' 'Jair' 'Valdir' 'ilda']
# Quantidade Treino: 4691
# Quantidade Teste: 3706
# Fadiga
# 0    4013
# 1     678
# Name: count, dtype: int64
# Fadiga
# 0    678
# 1    678
# Name: count, dtype: int64
# Fold 2
# Pessoas Treino: ['Amaro' 'Arnaldo' 'Carlos' 'Elisabete' 'Iria' 'Izabel' 'Katia' 'Reinaldo'
#  'Teresinha' 'Valdir' 'ilda' 'mariajose']
# Pessoas Teste: ['Adilson' 'Jair' 'Josui' 'Marilene' 'Nelson']
# Quantidade Treino: 6086
# Quantidade Teste: 2311
# Fadiga
# 0    5203
# 1     883
# Name: count, dtype: int64
# Fadiga
# 0    883
# 1    883
# Name: count, dtype: int64
# Fold 3
# Pessoas Treino: ['Adilson' 'Amaro' 'Arnaldo' 'Carlos' 'Elisabete' 'Izabel' 'Jair' 'Josui'
#  'Katia' 'Nelson' 'ilda' 'mariajose']
# Pessoas Teste: ['Iria' 'Marilene' 'Reinaldo' 'Teresinha' 'Valdir']
# Quantidade Treino: 5257
# Quantidade Teste: 3140
# Fadiga
# 0    4441
# 1     816
# Name: count, dtype: int64
# Fadiga
# 0    816
# 1    816
# Name: count, dtype: int64
# Fold 4
# Pessoas Treino: ['Adilson' 'Arnaldo' 'Elisabete' 'Iria' 'Izabel' 'Jair' 'Josui' 'Marilene'
#  'Reinaldo' 'Teresinha' 'ilda' 'mariajose']
# Pessoas Teste: ['Amaro' 'Carlos' 'Katia' 'Nelson' 'Valdir']
# Quantidade Treino: 5887
# Quantidade Teste: 2510
# Fadiga
# 0    5108
# 1     779
# Name: count, dtype: int64
# Fadiga
# 0    779
# 1    779
# Name: count, dtype: int64
# Fold 5
# Pessoas Treino: ['Adilson' 'Amaro' 'Arnaldo' 'Iria' 'Izabel' 'Josui' 'Katia' 'Marilene'
#  'Reinaldo' 'Teresinha' 'Valdir' 'mariajose']
# Pessoas Teste: ['Carlos' 'Elisabete' 'Jair' 'Nelson' 'ilda']
# Quantidade Treino: 5851
# Quantidade Teste: 2546
# Fadiga
# 0    5104
# 1     747
# Name: count, dtype: int64
# Fadiga
# 0    747
# 1    747
# Name: count, dtype: int64
# Fold 6
# Pessoas Treino: ['Adilson' 'Amaro' 'Arnaldo' 'Carlos' 'Elisabete' 'Iria' 'Josui'
#  'Marilene' 'Reinaldo' 'Teresinha' 'Valdir' 'mariajose']
# Pessoas Teste: ['Izabel' 'Jair' 'Katia' 'Nelson' 'ilda']
# Quantidade Treino: 6038
# Quantidade Teste: 2359
# Fadiga
# 0    5028
# 1    1010
# Name: count, dtype: int64
# Fadiga
# 0    1010
# 1    1010
# Name: count, dtype: int64
# Fold 7
# Pessoas Treino: ['Adilson' 'Amaro' 'Arnaldo' 'Iria' 'Josui' 'Katia' 'Marilene' 'Reinaldo'
#  'Teresinha' 'Valdir' 'ilda' 'mariajose']
# Pessoas Teste: ['Carlos' 'Elisabete' 'Izabel' 'Jair' 'Nelson']
# Quantidade Treino: 6073
# Quantidade Teste: 2324
# Fadiga
# 0    5304
# 1     769
# Name: count, dtype: int64
# Fadiga
# 0    769
# 1    769
# Name: count, dtype: int64
# Fold 8
# Pessoas Treino: ['Adilson' 'Arnaldo' 'Carlos' 'Iria' 'Izabel' 'Jair' 'Josui' 'Nelson'
#  'Teresinha' 'Valdir' 'ilda' 'mariajose']
# Pessoas Teste: ['Amaro' 'Elisabete' 'Katia' 'Marilene' 'Reinaldo']
# Quantidade Treino: 5915
# Quantidade Teste: 2482
# Fadiga
# 0    5137
# 1     778
# Name: count, dtype: int64
# Fadiga
# 0    778
# 1    778
# Name: count, dtype: int64
# Fold 9
# Pessoas Treino: ['Adilson' 'Amaro' 'Carlos' 'Iria' 'Izabel' 'Josui' 'Katia' 'Marilene'
#  'Nelson' 'Reinaldo' 'ilda' 'mariajose']
# Pessoas Teste: ['Arnaldo' 'Elisabete' 'Jair' 'Teresinha' 'Valdir']
# Quantidade Treino: 4769
# Quantidade Teste: 3628
# Fadiga
# 0    4122
# 1     647
# Name: count, dtype: int64
# Fadiga
# 0    647
# 1    647
# Name: count, dtype: int64

# %%
acuracias_knn = []
f1_score_knn = []
for X_train, y_train, X_test, y_test in zip(train_data_x, train_labels_y, test_data_x, test_labels_y):
    clf = Catch22Classifier(
        estimator = KNeighborsTimeSeriesClassifier(distance=dtw_distance, n_neighbors = 5), 
        replace_nans=True,
        outlier_norm=True,
        random_state=0,
    )
    clf.fit(X_train, y_train)
    predicts = clf.predict(X_test)
    acuracias_knn.append(metrics.accuracy_score(y_test, predicts))
    f1_score_knn.append(metrics.f1_score(y_test, predicts, average='weighted'))

# %%
print(acuracias_knn)
print(f1_score_knn)
melhor_fold = np.argmax(f1_score_knn)
# Out:
# [0.5731593662628145, 0.5731246627091203, 0.6633491994807442, 0.5321656050955414, 0.4848605577689243, 0.6732128829536528, 0.7363289529461636, 0.6536144578313253, 0.7087026591458501, 0.5898566703417861]
# [0.6523616108125921, 0.6450929684170565, 0.7208775011279916, 0.6257252012926461, 0.5630670016044743, 0.711764653269515, 0.8094102660042735, 0.6971816477456801, 0.7269373902694848, 0.655872872108743]

# %% [markdown]
# ### Visualizar o melhor resultado

# %%
X_train, y_train, X_test, y_test = train_data_x[melhor_fold], train_labels_y[melhor_fold], test_data_x[melhor_fold], test_labels_y[melhor_fold]
clf = Catch22Classifier(
    estimator = KNeighborsTimeSeriesClassifier(distance=dtw_distance, n_neighbors = 5), 
    replace_nans=True,
    outlier_norm=True,
    random_state=0,
)
clf.fit(X_train, y_train)
# Out:
# Catch22Classifier(estimator=KNeighborsTimeSeriesClassifier(distance=CPUDispatcher(<function dtw_distance at 0x71e8775bc220>),
#                                                            n_neighbors=5),
#                   outlier_norm=True, random_state=0)

# %%
predicts = clf.predict(X_test)

acc = accuracy_score(y_test,predicts)
print(acc)
# Out:
# 0.7363289529461636

# %%
print(classification_report(y_test,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84      2243
#            1       0.08      0.39      0.13       116
#
#     accuracy                           0.74      2359
#    macro avg       0.52      0.57      0.49      2359
# weighted avg       0.92      0.74      0.81      2359

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test,predicts)

# %% [markdown]
# ### Classificação de 1 pessoa

# %%
pessoa, labels = test_uma_pessoa(df_filtrado[df_filtrado['Nome'] == 'Jair'])
pessoa_x = []
for i in pessoa:
    pessoa_x.append(np.array(i).reshape(1,len(i)))
labels_y = np.array(labels)

# %%
predicts = clf.predict(pessoa_x)

acc = accuracy_score(labels_y,predicts)
print(acc)
# Out:
# 0.8143459915611815

# %%
print(classification_report(labels_y,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.84      0.90       902
#            1       0.10      0.37      0.16        46
#
#     accuracy                           0.81       948
#    macro avg       0.53      0.60      0.53       948
# weighted avg       0.92      0.81      0.86       948

# %%
disp = ConfusionMatrixDisplay.from_predictions(labels_y,predicts)

# %%
y = 0
count = 0
column_y = []
column_x = []
label = []
for serie in pessoa_x:
    for line in serie:
        for x in line:
            if labels_y[count] == 1 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(x)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(x)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(x)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 1 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(x)
                label.append('FN')

            y += 1
        count += 1 
teste_df = pd.DataFrame({'x':column_x,'y':column_y,'label':label})

# %%
teste_df.to_excel("resultados/Jair.xlsx", index=False)

# %% [markdown]
# ### KNN melhor parametros

# %%
X_train, y_train, X_test, y_test = train_data_x[melhor_fold], train_labels_y[melhor_fold], test_data_x[melhor_fold], test_labels_y[melhor_fold]

# %%
melhor_acc_knn = 0.0
melhor_parm_k = 0
melhor_parm_knn = [0,'']
distances = ['euclidean','squared','manhattan','minkowski','dtw']
for dist in distances:
    for k in range(1,25):
        clf = Catch22Classifier(
        estimator = KNeighborsTimeSeriesClassifier(distance=dist, n_neighbors = k), #RandomForestClassifier(n_estimators=100),
            replace_nans=True,
            outlier_norm=True,
            random_state=0,
        )
        clf.fit(X_train, y_train)
        predicts = clf.predict(X_test)
        acc = accuracy_score(y_test,predicts)
        print(f'Distance: {dist}, k: {k} Acuracy:{acc}')
        if(melhor_acc_knn < acc):
            melhor_acc = acc
            melhor_parm_knn[0] = k
            melhor_parm_knn[1] = dist
# Out:
# Distance: euclidean, k: 1 Acuracy:0.6596015260703688
# Distance: euclidean, k: 2 Acuracy:0.807969478592624
# Distance: euclidean, k: 3 Acuracy:0.6693514200932599
# Distance: euclidean, k: 4 Acuracy:0.8143281051292921
# Distance: euclidean, k: 5 Acuracy:0.7248834251801611
# Distance: euclidean, k: 6 Acuracy:0.8050021195421789
# Distance: euclidean, k: 7 Acuracy:0.7359050445103857
# Distance: euclidean, k: 8 Acuracy:0.8143281051292921
# Distance: euclidean, k: 9 Acuracy:0.7435353963543875
# Distance: euclidean, k: 10 Acuracy:0.8291649003815176
# Distance: euclidean, k: 11 Acuracy:0.7617634590928359
# Distance: euclidean, k: 12 Acuracy:0.8092412038999576
# Distance: euclidean, k: 13 Acuracy:0.7723611699872828
# Distance: euclidean, k: 14 Acuracy:0.804578211106401
# Distance: euclidean, k: 15 Acuracy:0.7757524374735058
# Distance: euclidean, k: 16 Acuracy:0.8139041966935142
# Distance: euclidean, k: 17 Acuracy:0.7842306061890632
# Distance: euclidean, k: 18 Acuracy:0.8100890207715133
# Distance: euclidean, k: 19 Acuracy:0.7918609580330649
# Distance: euclidean, k: 20 Acuracy:0.8172954641797372
# Distance: euclidean, k: 21 Acuracy:0.8054260279779568
# Distance: euclidean, k: 22 Acuracy:0.8236540907164053
# Distance: euclidean, k: 23 Acuracy:0.8117846545146249
# Distance: euclidean, k: 24 Acuracy:0.8308605341246291
# Distance: squared, k: 1 Acuracy:0.6596015260703688
# Distance: squared, k: 2 Acuracy:0.807969478592624
# Distance: squared, k: 3 Acuracy:0.6693514200932599
# Distance: squared, k: 4 Acuracy:0.8143281051292921
# Distance: squared, k: 5 Acuracy:0.7248834251801611
# Distance: squared, k: 6 Acuracy:0.8050021195421789
# Distance: squared, k: 7 Acuracy:0.7359050445103857
# Distance: squared, k: 8 Acuracy:0.8143281051292921
# Distance: squared, k: 9 Acuracy:0.7435353963543875
# Distance: squared, k: 10 Acuracy:0.8291649003815176
# Distance: squared, k: 11 Acuracy:0.7617634590928359
# Distance: squared, k: 12 Acuracy:0.8092412038999576
# Distance: squared, k: 13 Acuracy:0.7723611699872828
# Distance: squared, k: 14 Acuracy:0.804578211106401
# Distance: squared, k: 15 Acuracy:0.7757524374735058
# Distance: squared, k: 16 Acuracy:0.8139041966935142
# Distance: minkowski, k: 21 Acuracy:0.8054260279779568
# Distance: minkowski, k: 22 Acuracy:0.8236540907164053
# Distance: minkowski, k: 23 Acuracy:0.8117846545146249
# Distance: minkowski, k: 24 Acuracy:0.8308605341246291
# Distance: dtw, k: 1 Acuracy:0.6596015260703688
# Distance: dtw, k: 2 Acuracy:0.811360746078847
# Distance: dtw, k: 3 Acuracy:0.6676557863501483
# Distance: dtw, k: 4 Acuracy:0.8092412038999576
# Distance: dtw, k: 5 Acuracy:0.731665960152607
# Distance: dtw, k: 6 Acuracy:0.8062738448495125
# Distance: dtw, k: 7 Acuracy:0.73505722763883
# Distance: dtw, k: 8 Acuracy:0.8105129292072912
# Distance: dtw, k: 9 Acuracy:0.7511657481983891
# Distance: dtw, k: 10 Acuracy:0.8261975413310725
# Distance: dtw, k: 11 Acuracy:0.7676981771937261
# Distance: dtw, k: 12 Acuracy:0.8105129292072912
# Distance: dtw, k: 13 Acuracy:0.7770241627808393
# Distance: dtw, k: 14 Acuracy:0.8054260279779568
# Distance: dtw, k: 15 Acuracy:0.7808393387028402
# Distance: dtw, k: 16 Acuracy:0.8155998304366257
# Distance: dtw, k: 17 Acuracy:0.7876218736752861
# Distance: dtw, k: 18 Acuracy:0.811360746078847
# Distance: dtw, k: 19 Acuracy:0.7897414158541755
# Distance: dtw, k: 20 Acuracy:0.8219584569732937
# Distance: dtw, k: 21 Acuracy:0.8075455701568461
# Distance: dtw, k: 22 Acuracy:0.8223823654090716
# Distance: dtw, k: 23 Acuracy:0.8096651123357355
# Distance: dtw, k: 24 Acuracy:0.8308605341246291

# %%
print(melhor_acc_knn)
print(melhor_parm_knn)
# Out:
# 0.0
# [24, 'dtw']

# %%
clf = Catch22Classifier(
estimator = KNeighborsTimeSeriesClassifier(distance=melhor_parm_knn[1], n_neighbors = melhor_parm_knn[0]), #RandomForestClassifier(n_estimators=100),
    replace_nans=True,
    outlier_norm=True,
    random_state=0,
)
clf.fit(X_train, y_train)
predicts = clf.predict(X_test)
acc = accuracy_score(y_test,predicts)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      2243
#            1       0.08      0.22      0.11       116
#
#     accuracy                           0.83      2359
#    macro avg       0.52      0.54      0.51      2359
# weighted avg       0.91      0.83      0.87      2359

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test,predicts)

# %% [markdown]
# ### Visualização 1 pessoa

# %%
pessoa, labels = test_uma_pessoa(df_filtrado[df_filtrado['Nome'] == 'Teresinha'])
pessoa_x = []
for i in pessoa:
    pessoa_x.append(np.array(i).reshape(1,len(i)))
labels_y = np.array(labels)

# %%
predicts = clf.predict(pessoa_x)

acc = accuracy_score(labels_y,predicts)
print(acc)
# Out:
# 0.6829971181556196

# %%
print(classification_report(labels_y,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80       315
#            1       0.12      0.38      0.18        32
#
#     accuracy                           0.68       347
#    macro avg       0.52      0.54      0.49       347
# weighted avg       0.84      0.68      0.75       347

# %%
disp = ConfusionMatrixDisplay.from_predictions(labels_y,predicts)

# %%
y = 0
count = 0
column_y = []
column_x = []
label = []
for serie in pessoa_x:
    for line in serie:
        for x in line:
            if labels_y[count] == 1 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(x)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(x)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(x)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 1 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(x)
                label.append('FN')

            y += 1
        count += 1 
teste_df = pd.DataFrame({'x':column_x,'y':column_y,'label':label})

# %%
teste_df.to_excel("resultados\Teresinha_knn.xlsx", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_2444/602980457.py:1: SyntaxWarning: invalid escape sequence '\T'
#   teste_df.to_excel("resultados\Teresinha_knn.xlsx", index=False)

# %% [markdown]
# ## Random Forest

# %%
X_train, y_train, X_test, y_test = train_data_x[melhor_fold], train_labels_y[melhor_fold], test_data_x[melhor_fold], test_labels_y[melhor_fold]

# %%
melhor_acc_tree = 0.0
melhor_parm_tree = 0
for tree in range(1,200):
    clf = Catch22Classifier(
    estimator = RandomForestClassifier(n_estimators = tree), #RandomForestClassifier(n_estimators=100),
        replace_nans=True,
        outlier_norm=True,
        random_state=0,
    )
    clf.fit(X_train, y_train)
    predicts = clf.predict(X_test)
    acc = accuracy_score(y_test,predicts)
    print(f'Trees:{tree} Acuracy:{acc}')
    if(melhor_acc_tree < acc):
        melhor_acc_tree = acc
        melhor_parm_tree = tree
# Out:
# Trees:1 Acuracy:0.7447833065810594
# Trees:2 Acuracy:0.8756019261637239
# Trees:3 Acuracy:0.8174157303370787
# Trees:4 Acuracy:0.8691813804173355
# Trees:5 Acuracy:0.819422150882825
# Trees:6 Acuracy:0.8647672552166934
# Trees:7 Acuracy:0.8290529695024077
# Trees:8 Acuracy:0.8671749598715891
# Trees:9 Acuracy:0.8322632423756019
# Trees:10 Acuracy:0.8523274478330658
# Trees:11 Acuracy:0.836677367576244
# Trees:12 Acuracy:0.8579454253611557
# Trees:13 Acuracy:0.8362760834670947
# Trees:14 Acuracy:0.8615569823434992
# Trees:15 Acuracy:0.843900481540931
# Trees:16 Acuracy:0.8599518459069021
# Trees:17 Acuracy:0.8398876404494382
# Trees:18 Acuracy:0.8571428571428571
# Trees:19 Acuracy:0.8350722311396469
# Trees:20 Acuracy:0.8539325842696629
# Trees:21 Acuracy:0.8451043338683788
# Trees:22 Acuracy:0.858346709470305
# Trees:23 Acuracy:0.8455056179775281
# Trees:24 Acuracy:0.8527287319422151
# Trees:25 Acuracy:0.8414927768860353
# Trees:26 Acuracy:0.8527287319422151
# Trees:27 Acuracy:0.8386837881219904
# Trees:28 Acuracy:0.8503210272873194
# Trees:29 Acuracy:0.8402889245585875
# Trees:30 Acuracy:0.8467094703049759
# Trees:31 Acuracy:0.8334670947030498
# Trees:32 Acuracy:0.843900481540931
# Trees:33 Acuracy:0.8382825040128411
# Trees:34 Acuracy:0.8451043338683788
# Trees:35 Acuracy:0.8390850722311396
# Trees:36 Acuracy:0.8447030497592295
# Trees:178 Acuracy:0.862760834670947
# Trees:179 Acuracy:0.8603531300160514
# Trees:180 Acuracy:0.8639646869983949
# Trees:181 Acuracy:0.8623595505617978
# Trees:182 Acuracy:0.8635634028892456
# Trees:183 Acuracy:0.8619582664526485
# Trees:184 Acuracy:0.8639646869983949
# Trees:185 Acuracy:0.8619582664526485
# Trees:186 Acuracy:0.8635634028892456
# Trees:187 Acuracy:0.8631621187800963
# Trees:188 Acuracy:0.8635634028892456
# Trees:189 Acuracy:0.8607544141252006
# Trees:190 Acuracy:0.8623595505617978
# Trees:191 Acuracy:0.8615569823434992
# Trees:192 Acuracy:0.8639646869983949
# Trees:193 Acuracy:0.8607544141252006
# Trees:194 Acuracy:0.8647672552166934
# Trees:195 Acuracy:0.862760834670947
# Trees:196 Acuracy:0.8639646869983949
# Trees:197 Acuracy:0.8635634028892456
# Trees:198 Acuracy:0.8647672552166934
# Trees:199 Acuracy:0.8635634028892456

# %%
print(melhor_acc_tree)
print(melhor_parm_tree)
# Out:
# 0.8756019261637239
# 2

# %%
clf = Catch22Classifier(
estimator = RandomForestClassifier(n_estimators = melhor_parm_tree), #RandomForestClassifier(n_estimators=100),
    replace_nans=True,
    outlier_norm=True,
    random_state=0,
)
clf.fit(X_train, y_train)
predicts = clf.predict(X_test)
acc = accuracy_score(y_test,predicts)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      2348
#            1       0.18      0.31      0.23       144
#
#     accuracy                           0.88      2492
#    macro avg       0.57      0.61      0.58      2492
# weighted avg       0.91      0.88      0.89      2492

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test,predicts)

# %% [markdown]
# ### Uma Pessoa Random Forest

# %%
pessoa, labels = test_uma_pessoa(df_filtrado[df_filtrado['Nome'] == 'Teresinha'])
pessoa_x = []
for i in pessoa:
    pessoa_x.append(np.array(i).reshape(1,len(i)))
labels_y = np.array(labels)

# %%
predicts = clf.predict(pessoa_x)

acc = accuracy_score(labels_y,predicts)
print(acc)
# Out:
# 0.7694524495677233

# %%
print(classification_report(labels_y,predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       315
#            1       0.11      0.22      0.15        32
#
#     accuracy                           0.77       347
#    macro avg       0.51      0.52      0.51       347
# weighted avg       0.84      0.77      0.80       347

# %%
disp = ConfusionMatrixDisplay.from_predictions(labels_y,predicts)

# %%
y = 0
count = 0
column_y = []
column_x = []
label = []
for serie in pessoa_x:
    for line in serie:
        for x in line:
            if labels_y[count] == 1 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(x)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(x)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 0 and predicts[count] == 1:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(x)
                label.append('FP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FN')
            if labels_y[count] == 1 and predicts[count] == 0:
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TP')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('TN')
                column_y.append(y)
                column_x.append(np.nan)
                label.append('FP')
                column_y.append(y)
                column_x.append(x)
                label.append('FN')

            y += 1
        count += 1 
teste_df = pd.DataFrame({'x':column_x,'y':column_y,'label':label})

# %%
teste_df.to_excel("resultados\Teresinha_rf.xlsx", index=False)
