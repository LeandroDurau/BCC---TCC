# %%
from numpy.lib import median
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %% [markdown]
# ## Carga da Base

# %%
df_total = pd.DataFrame()
id_pessoa = 0
for i in os.listdir('normalizacao/'):
    df = pd.read_excel(f"normalizacao/{i}",header=None)
    df['Nome'] = id_pessoa
    id_pessoa += 1
    #df['Nome'] = i.split('-')[1].split('.')[0]
    df_total = pd.concat([df,df_total])
df_total = df_total.rename(columns={1:'Qtd Total Pontos',2:'Qtd Dados'})

# %%
df_total['Fadiga'] = [0 if x == 'Normal' else 1 for x in df_total[0]]
df_total
# Out:
#                   0  Qtd Total Pontos  Qtd Dados           3           4  \
# 0            Normal               250        249  617.690186  617.679871
# 1            Normal               206        206  905.522034  905.256958
# 2    Erro na Coleta              1290        689  599.337158  603.076416
# 3    Erro na Coleta               120         99  750.602417  749.031067
# 4    Erro na Coleta               277         92  624.175659  624.377319
# ..              ...               ...        ...         ...         ...
# 166          Normal               177        175  585.330566  585.392761
# 167          Normal               226        225  869.773010  869.624756
# 168          Normal               212        212  586.307861  586.316895
# 169          Normal               200        200  862.808289  863.046753
# 170          Normal               251        250  587.927490  587.966492
#
#               5           6           7           8           9  ...  6998  \
# 0    617.748291  617.704529  617.624207  617.557251  617.412354  ...   NaN
# 1    905.053467  904.930481  904.830872  904.792175  904.865112  ...   NaN
# 2    606.548157  609.216492  610.949463  611.528442  611.240906  ...   NaN
# 3    747.358887  745.603943  743.997986  742.309265  740.471191  ...   NaN
# 4    624.488586  624.601196  624.832397  625.039429  625.369690  ...   NaN
# ..          ...         ...         ...         ...         ...  ...   ...
# 166  585.384583  585.461975  585.557800  585.493591  585.342041  ...   NaN
# 167  869.500549  869.216614  869.062622  868.875000  868.664856  ...   NaN
# 168  586.388367  586.399536  586.374939  586.223206  586.212463  ...   NaN
# 169  863.196655  863.211609  863.170715  863.205017  863.242798  ...   NaN
# 170  588.002808  588.005859  587.982727  587.918945  587.883606  ...   NaN
#
#      6999  7000  7001  7002  7003  7004  7005  7006  Fadiga
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# ..    ...   ...   ...   ...   ...   ...   ...   ...     ...
# 166   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 167   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 168   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 169   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 170   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
# [8538 rows x 7009 columns]

# %%
ax = sns.countplot(y=df_total[0])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '7331'),
#  Text(0, 0, '58'),
#  Text(0, 0, '79'),
#  Text(0, 0, '70'),
#  Text(0, 0, '6'),
#  Text(0, 0, '333'),
#  Text(0, 0, '589'),
#  Text(0, 0, '1'),
#  Text(0, 0, '13'),
#  Text(0, 0, '19'),
#  Text(0, 0, '14'),
#  Text(0, 0, '25')]

# %%
sns.countplot(y=df_total['Nome'])
# Out:
# <Axes: xlabel='count', ylabel='Nome'>

# %%
# teste = df_total.groupby(['Nome'])['Fadiga'].value_counts()
# nome = []
# classe = []
# for i in teste.index:
#     nome.append(i[0])
#     if i[1] == 1:
#         classe.append('Anormal')
#     else:
#         classe.append('Normal')

# df_teste = pd.DataFrame({'Quantidade de Segmentos':teste.values, 'Nome':nome, 'classe': classe})
# #f, ax =plt.subplots(figsize=(6,15))
# ax = sns.barplot(df_teste, x='Quantidade de Segmentos', y='Nome', hue='classe',orient="y")
# ax.bar_label(ax.containers[0], fontsize = 7);
# ax.bar_label(ax.containers[1], fontsize = 7);
# ax.legend(ncol=2, loc='lower right', frameon=True)
# plt.title('Quantidade de Segmentos por Pessoa')
# plt.show()

# %% [markdown]
# ## Quantidade de dados de cada Subida/Descida

# %%
df_total['%De N Vazios'] = df_total['Qtd Dados'] / df_total['Qtd Total Pontos']

# %%
fig, ax = plt.subplots()
sns.histplot(x='Qtd Dados',data=df_total)
ax.set_xlim(-1, 1000)
plt.title('Qtd Dados')
plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(x='Qtd Total Pontos',data=df_total)
ax.set_xlim(-1, 1000)
plt.title('Tamanho da Serie')
plt.show()

# %%
df_total['%De Vazios'] = df_total['Qtd Dados']/ df_total['Qtd Total Pontos']

# %%
fig, ax = plt.subplots()
sns.histplot(x='%De N Vazios',data=df_total)
ax.set_xlim(0.8,1.01)
plt.title('%De Não Vazios')
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(x='Qtd Dados',data=df_total, ax=ax)
ax.set_xlim(-1, 1000)
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(x='Qtd Total Pontos',data=df_total, ax=ax)
ax.set_xlim(-1, 1000)
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(x='%De N Vazios',data=df_total, ax=ax)
ax.set_xlim(0.8,1.1)
plt.show()

# %%
df_total['%De N Vazios'][df_total['%De N Vazios'] < 0.85].count()
# Out:
# 45

# %%
df_total['%De N Vazios'][(df_total['%De N Vazios'] < 0.85) & (df_total[0] != 'Erro na Coleta')].count()
# Out:
# 22

# %%
porcentagem = 0.85
nome = df_total[df_total['%De N Vazios'] < porcentagem]['Nome'].to_numpy()
anot = df_total[df_total['%De N Vazios'] < porcentagem][0].to_numpy()
dados = df_total[df_total['%De N Vazios'] < porcentagem]['Qtd Dados'].to_numpy()
pontos = df_total[df_total['%De N Vazios'] < porcentagem]['Qtd Total Pontos'].to_numpy()
count = 0
for x in df_total[df_total['%De N Vazios'] < porcentagem].drop([0,'Nome','Qtd Dados','Qtd Total Pontos','%De N Vazios','Fadiga'],axis = 1).to_numpy():
    plt.plot(x[:pontos[count]])
    plt.title('Caso com menos de 85% de Pontos não nulos')
    count += 1
    plt.show()

# %% [markdown]
# ## Primeira Filtragem

# %%
df_filtrado = df_total[(df_total['%De N Vazios'] > 0.85) & (df_total[0] != 'Erro na Coleta')]# & (df_total['Qtd Total Pontos'] < 500)]

fig, ax = plt.subplots()
sns.boxplot(x='Qtd Dados',data=df_filtrado, ax=ax)
#ax.set_xlim(-1, 2000)
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(x='Qtd Total Pontos',data=df_filtrado, ax=ax)
#ax.set_xlim(-1, 1000)
plt.show()

# %%
df_filtrado['Qtd Total Pontos'][df_filtrado['Qtd Total Pontos'] > 500].count()
# Out:
# 15

# %%
tamanho = 500
nome = df_filtrado[df_filtrado['Qtd Total Pontos'] > tamanho]['Nome'].to_numpy()
anot = df_filtrado[df_filtrado['Qtd Total Pontos'] > tamanho][0].to_numpy()
dados = df_filtrado[df_filtrado['Qtd Total Pontos'] > tamanho]['Qtd Dados'].to_numpy()
pontos = df_filtrado[df_filtrado['Qtd Total Pontos'] > tamanho]['Qtd Total Pontos'].to_numpy()
count = 0
for x in df_filtrado[df_filtrado['Qtd Total Pontos'] > tamanho].drop([0,'Nome','Qtd Dados','Qtd Total Pontos','%De N Vazios','Fadiga'],axis = 1).to_numpy():
    plt.plot(x[:pontos[count]])
    print(x)
    plt.title('Caso com mais de 500 Frames')
    count += 1
    plt.show()
# Out:
# [603.678528 603.788086 603.911194 ...        nan        nan   1.      ]
# [952.896484   952.920044   953.004883   ...          nan          nan
#    0.96459227]
# [572.095398   572.401611   571.013062   ...          nan          nan
#    0.99894217]
# [591.779053   591.746338   591.723999   ...          nan          nan
#    0.98181818]
# [877.373169   877.584167   877.696716   ...          nan          nan
#    0.99032882]
# [872.077271   871.68866    871.27948    ...          nan          nan
#    0.97731569]
# [871.902649   870.82428    869.731201   ...          nan          nan
#    0.97813121]
# [597.730774 597.942322 597.889038 ...        nan        nan   1.      ]
# [822.728699   822.708069   822.689453   ...          nan          nan
#    0.98959881]
# [605.03894    604.360596   603.751099   ...          nan          nan
#    0.99834711]
# [932.516418   932.516113   932.545288   ...          nan          nan
#    0.99294118]
# [602.246338   598.717407   602.751465   ...          nan          nan
#    0.99286733]
# [790.627075  790.450012  790.34259   ...         nan         nan
#    0.9914966]
# [732.332764   732.516602   732.566772   ...          nan          nan
#    0.99378882]
# [736.656616   736.535217   736.352539   ...          nan          nan
#    0.99063963]

# %% [markdown]
# ## Segunda Filtragem

# %%
df_filtrado2 = df_total[(df_total['%De N Vazios'] > 0.85) & (df_total[0] != 'Erro na Coleta') & 
    ((df_total['Qtd Total Pontos'] < 500) | (df_total[0] == 'Platô')) & 
    (df_total['Qtd Total Pontos'] < 1000)]

fig, ax = plt.subplots()
sns.boxplot(x='Qtd Dados',data=df_filtrado2, ax=ax)
#ax.set_xlim(-1, 2000)
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(x='Qtd Total Pontos',data=df_filtrado2, ax=ax)
#ax.set_xlim(-1, 2000)
plt.show()

# %%
df_filtrado2['Qtd Total Pontos'][df_filtrado2['Qtd Total Pontos'] <80].count()
# Out:
# 9

# %%
tamanho = 80
nome = df_filtrado2[df_filtrado2['Qtd Total Pontos'] < tamanho]['Nome'].to_numpy()
anot = df_filtrado2[df_filtrado2['Qtd Total Pontos'] < tamanho][0].to_numpy()
dados = df_filtrado2[df_filtrado2['Qtd Total Pontos'] < tamanho]['Qtd Dados'].to_numpy()
pontos = df_filtrado2[df_filtrado2['Qtd Total Pontos'] < tamanho]['Qtd Total Pontos'].to_numpy()
count = 0
for x in df_filtrado2[df_filtrado2['Qtd Total Pontos'] < tamanho].drop([0,'Nome','Qtd Dados','Qtd Total Pontos','%De N Vazios'],axis = 1).to_numpy():
    x = pd.Series(x[:pontos[count]]).interpolate().to_numpy()
    plt.plot(x)
    plt.title(nome[count]+ '-'+ anot[count]+'-'+str(dados[count])+'-'+str(pontos[count])+' %'+str(dados[count]/pontos[count]*100))
    count += 1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[25], line 10
#       8 x = pd.Series(x[:pontos[count]]).interpolate().to_numpy()
#       9 plt.plot(x)
# ---> 10 plt.title(nome[count]+ '-'+ anot[count]+'-'+str(dados[count])+'-'+str(pontos[count])+' %'+str(dados[count]/pontos[count]*100))
#      11 count += 1
#      12 plt.show()
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('int64'), dtype('<U1')) -> None
