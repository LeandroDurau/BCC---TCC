# %%
from numpy.lib import median
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df_total = pd.DataFrame()
id_pessoa = 0
for i in os.listdir('normalizacao/'):
    df = pd.read_excel(f"normalizacao/{i}",header=None)
    df['Nome'] = id_pessoa
    id_pessoa += 1
    #df['Nome'] = i.split('-')[1].split('.')[0]
    df_total = pd.concat([df,df_total])
df_total = df_total.rename(columns={1:'Qtd Total Pontos',2:'Qtd Dados'})

# %%
df_total['Fadiga'] = [0 if x == 'Normal' else 1 for x in df_total[0]]
df_total
# Out:
#                   0  Qtd Total Pontos  Qtd Dados           3           4  \
# 0            Normal               250        249  617.690186  617.679871
# 1            Normal               206        206  905.522034  905.256958
# 2    Erro na Coleta              1290        689  599.337158  603.076416
# 3    Erro na Coleta               120         99  750.602417  749.031067
# 4    Erro na Coleta               277         92  624.175659  624.377319
# ..              ...               ...        ...         ...         ...
# 166          Normal               177        175  585.330566  585.392761
# 167          Normal               226        225  869.773010  869.624756
# 168          Normal               212        212  586.307861  586.316895
# 169          Normal               200        200  862.808289  863.046753
# 170          Normal               251        250  587.927490  587.966492
#
#               5           6           7           8           9  ...  6998  \
# 0    617.748291  617.704529  617.624207  617.557251  617.412354  ...   NaN
# 1    905.053467  904.930481  904.830872  904.792175  904.865112  ...   NaN
# 2    606.548157  609.216492  610.949463  611.528442  611.240906  ...   NaN
# 3    747.358887  745.603943  743.997986  742.309265  740.471191  ...   NaN
# 4    624.488586  624.601196  624.832397  625.039429  625.369690  ...   NaN
# ..          ...         ...         ...         ...         ...  ...   ...
# 166  585.384583  585.461975  585.557800  585.493591  585.342041  ...   NaN
# 167  869.500549  869.216614  869.062622  868.875000  868.664856  ...   NaN
# 168  586.388367  586.399536  586.374939  586.223206  586.212463  ...   NaN
# 169  863.196655  863.211609  863.170715  863.205017  863.242798  ...   NaN
# 170  588.002808  588.005859  587.982727  587.918945  587.883606  ...   NaN
#
#      6999  7000  7001  7002  7003  7004  7005  7006  Fadiga
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       1
# ..    ...   ...   ...   ...   ...   ...   ...   ...     ...
# 166   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 167   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 168   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 169   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 170   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
# [8538 rows x 7009 columns]

# %%
df_total['Fadiga_texto'] = ['Normal' if x == 'Normal' else 'Anormal' for x in df_total[0]]
df_total
# Out:
#                   0  Qtd Total Pontos  Qtd Dados           3           4  \
# 0            Normal               250        249  617.690186  617.679871
# 1            Normal               206        206  905.522034  905.256958
# 2    Erro na Coleta              1290        689  599.337158  603.076416
# 3    Erro na Coleta               120         99  750.602417  749.031067
# 4    Erro na Coleta               277         92  624.175659  624.377319
# ..              ...               ...        ...         ...         ...
# 166          Normal               177        175  585.330566  585.392761
# 167          Normal               226        225  869.773010  869.624756
# 168          Normal               212        212  586.307861  586.316895
# 169          Normal               200        200  862.808289  863.046753
# 170          Normal               251        250  587.927490  587.966492
#
#               5           6           7           8           9  ...  6999  \
# 0    617.748291  617.704529  617.624207  617.557251  617.412354  ...   NaN
# 1    905.053467  904.930481  904.830872  904.792175  904.865112  ...   NaN
# 2    606.548157  609.216492  610.949463  611.528442  611.240906  ...   NaN
# 3    747.358887  745.603943  743.997986  742.309265  740.471191  ...   NaN
# 4    624.488586  624.601196  624.832397  625.039429  625.369690  ...   NaN
# ..          ...         ...         ...         ...         ...  ...   ...
# 166  585.384583  585.461975  585.557800  585.493591  585.342041  ...   NaN
# 167  869.500549  869.216614  869.062622  868.875000  868.664856  ...   NaN
# 168  586.388367  586.399536  586.374939  586.223206  586.212463  ...   NaN
# 169  863.196655  863.211609  863.170715  863.205017  863.242798  ...   NaN
# 170  588.002808  588.005859  587.982727  587.918945  587.883606  ...   NaN
#
#      7000  7001  7002  7003  7004  7005  7006  Fadiga  Fadiga_texto
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 1     NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 2     NaN   NaN   NaN   NaN   NaN   NaN   NaN       1       Anormal
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN       1       Anormal
# 4     NaN   NaN   NaN   NaN   NaN   NaN   NaN       1       Anormal
# ..    ...   ...   ...   ...   ...   ...   ...     ...           ...
# 166   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 167   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 168   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 169   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
# 170   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0        Normal
#
# [8538 rows x 7010 columns]

# %%
def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{:.1f}%\n({v:d})'.format(pct, v=val)
        return my_format

pie = df_total['Fadiga_texto'].value_counts()
plt.pie(pie, labels = pie.index, autopct=autopct_format(pie))
plt.title('Distribuicão dos Dados de Classificacão')
# Out:
# Text(0.5, 1.0, 'Distribuicão dos Dados de Classificacão')

# %%
teste = df_total.groupby(['Nome'])['Fadiga'].value_counts()
nome = []
classe = []
for i in teste.index:
    nome.append(i[0])
    if i[1] == 1:
        classe.append('Anormal')
    else:
        classe.append('Normal')

df_teste = pd.DataFrame({'Quantidade de Segmentos':teste.values, 'Nome':nome, 'classe': classe})
#f, ax =plt.subplots(figsize=(6,15))
ax = sns.barplot(df_teste, x='Quantidade de Segmentos', y='Nome', hue='classe',orient="y")
ax.bar_label(ax.containers[0], fontsize = 7);
ax.bar_label(ax.containers[1], fontsize = 7);
ax.legend(ncol=2, loc='lower right', frameon=True)
plt.title('Quantidade de Segmentos por Pessoa')
plt.show()

# %%
#

# %%
total_pontos = df_total.groupby(['Nome'])['Qtd Total Pontos'].sum()
print(total_pontos)
# Out:
# Nome
# Adilson       50753
# Amaro        120517
# Arnaldo      122178
# Carlos        76119
# Elisabete     91527
# Iria          39520
# Izabel        96567
# Jair         169461
# Josefina      19047
# Josui        106291
# Katia         30953
# Marilene     100694
# Nelson        37522
# Reinaldo     157280
# Teresinha     86333
# Valdir       215860
# ilda         134448
# mariajose     53417
# Name: Qtd Total Pontos, dtype: int64

# %%
np.max(total_pontos)
# Out:
# 215860

# %%
#

# %%
total_series = df_total.groupby(['Nome'])[0].count()
print(total_series)
# Out:
# Nome
# Adilson       237
# Amaro         608
# Arnaldo       613
# Carlos        346
# Elisabete     432
# Iria          171
# Izabel        463
# Jair          961
# Josefina       70
# Josui         514
# Katia         121
# Marilene      485
# Nelson        148
# Reinaldo      848
# Teresinha     348
# Valdir       1300
# ilda          684
# mariajose     189
# Name: 0, dtype: int64

# %%
np.max(total_series)
# Out:
# 1300

# %%
#

# %%
demora_serie = df_total.groupby(['Nome'])['Qtd Total Pontos'].mean()
print(demora_serie)
# Out:
# Nome
# Adilson      214.147679
# Amaro        198.218750
# Arnaldo      199.311582
# Carlos       219.997110
# Elisabete    211.868056
# Iria         231.111111
# Izabel       208.568035
# Jair         176.338189
# Josefina     272.100000
# Josui        206.791829
# Katia        255.809917
# Marilene     207.616495
# Nelson       253.527027
# Reinaldo     185.471698
# Teresinha    248.083333
# Valdir       166.046154
# ilda         196.561404
# mariajose    282.629630
# Name: Qtd Total Pontos, dtype: float64

# %%
np.mean(demora_serie)
# Out:
# 218.56655547754454

# %%
df_total['Qtd Total Pontos'].max()
# Out:
# 7004

# %%
#

# %%
fadiga_pessoas = df_total[df_total['Fadiga'] == 1].groupby(['Nome'])[0].count()
print(fadiga_pessoas)
# Out:
# Nome
# Adilson        2
# Amaro         70
# Arnaldo      301
# Carlos       228
# Elisabete     64
# Iria          22
# Izabel        20
# Jair          57
# Josefina      22
# Josui         55
# Katia          5
# Marilene     151
# Nelson         7
# Reinaldo      68
# Teresinha     32
# Valdir        47
# ilda          42
# mariajose     14
# Name: 0, dtype: int64

# %%
np.max(fadiga_pessoas)
# Out:
# 301

# %%
pontos = df_total['Qtd Total Pontos'].sum()

# %%
n_nulos = df_total['Qtd Dados'].sum()

# %%
((pontos - n_nulos) / pontos) * 100
# Out:
# 1.7805812979554425
